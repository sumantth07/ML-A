# %%
import statsmodels.formula.api as smf
import pandas as pd
import matplotlib.pyplot as plt


df = pd.DataFrame({
    "X": [1, 2, 3, 4, 5],
    "y": [2.1, 4.2, 6.1, 8.3, 10.4]
})
model1 = smf.ols('y ~ X', data=df)
result = model1.fit()
print(result.summary())

ypred = result.predict(df["X"])
print(ypred)

print(f"Coefficients:\n{result.params}")
print(f"P-values:\n{result.pvalues}")
print(f"R-squared:\n{result.rsquared}")

plt.figure(figsize=(10, 5))
plt.plot(df['X'], df['y'], 'o', label='Actual Data')
plt.plot(df['X'], ypred, 'r', linewidth=2, label='Regression Line')  # Regression line
plt.xlabel('X values')
plt.ylabel('y values')
plt.title('Linear Regression Model using `statsmodels`')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                     6766.
# Date:                Tue, 07 Jan 2025   Prob (F-statistic):           3.96e-06
# Time:                        12:47:18   Log-Likelihood:                 6.8372
# No. Observations:                   5   AIC:                            -9.674
# Df Residuals:                       3   BIC:                            -10.46
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0100      0.083      0.120      0.912      -0.256       0.276
# X              2.0700      0.025     82.253      0.000       1.990       2.150
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.505
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.422
# Skew:                          -1.306   Prob(JB):                        0.491
# Kurtosis:                       2.996   Cond. No.                         8.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0     2.08
# 1     4.15
# 2     6.22
# 3     8.29
# 4    10.36
# dtype: float64
# Coefficients:
# Intercept    0.01
# X            2.07
# dtype: float64
# P-values:
# Intercept    0.912208
# X            0.000004
# dtype: float64
# R-squared:
# 0.9995567789493328
